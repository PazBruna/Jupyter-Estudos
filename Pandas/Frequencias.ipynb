# %% [markdown]
# # Frequências

# %% [markdown]
# #### Selecione somente os imoveis classificados com tipo 'Apartamento'
# #### Selecione os imoveis classificados com tipos 'Casa','Casa de condominio' e 'casa de vila'
# #### Selecione os imoveis com area entre 60 e 100 metros quadrados, incluindo limites
# #### Selecione os imoveis que tenham pelo menos 4 quartos e aluguel menos que 2.000

# %%
import pandas as pd

# %%
imoveis = pd.read_csv('dados/aluguel.csv', sep = ';')
imoveis
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 0                    Quitinete                Copacabana        1      0
# 1                         Casa           Jardim Botânico        2      0
# 2      Conjunto Comercial/Sala           Barra da Tijuca        0      4
# 3                  Apartamento                    Centro        1      0
# 4                  Apartamento              Higienópolis        1      0
# 5                  Apartamento              Vista Alegre        3      1
# 6                  Apartamento                  Cachambi        2      0
# 7           Casa de Condomínio           Barra da Tijuca        5      4
# 8           Casa de Condomínio                     Ramos        2      2
# 9      Conjunto Comercial/Sala                    Centro        0      3
# 10                 Apartamento                    Centro        1      0
# 11                 Apartamento                    Grajaú        2      1
# ...

# %%
tipo_apartamento = ['Apartamento']

# %%
tipo_apartamento
# Out:
# ['Apartamento']

# %%
imoveis_apartamento = imoveis['Tipo'].isin(tipo_apartamento)

# %%
imoveis_apartamento
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
# 5         True
# 6         True
# 7        False
# 8        False
# 9        False
# 10        True
# 11        True
# 12        True
# 13        True
# 14       False
# 15        True
# 16       False
# 17       False
# 18       False
# 19        True
# 20        True
# 21        True
# 22       False
# 23        True
# 24        True
# 25       False
# 26       False
# 27        True
# 28        True
# 29       False
#          ...
# 32930     True
# 32931    False
# 32932     True
# 32933     True
# 32934     True
# 32935     True
# 32936     True
# 32937    False
# 32938     True
# 32939    False
# 32940     True
# 32941     True
# 32942    False
# 32943     True
# 32944     True
# 32945    False
# 32946    False
# 32947     True
# 32948    False
# 32949     True
# 32950     True
# 32951     True
# 32952    False
# 32953     True
# 32954    False
# 32955    False
# 32956     True
# ...

# %%
imoveis_apartamento = imoveis[imoveis_apartamento]

# %%
imoveis_apartamento.index = range(imoveis_apartamento.shape[0])

# %%
imoveis_apartamento
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                    Centro        1      0       0    15
# 1      Apartamento              Higienópolis        1      0       0    48
# 2      Apartamento              Vista Alegre        3      1       0    70
# 3      Apartamento                  Cachambi        2      0       0    50
# 4      Apartamento                    Centro        1      0       0    36
# 5      Apartamento                    Grajaú        2      1       0    70
# 6      Apartamento       Lins de Vasconcelos        3      1       1    90
# 7      Apartamento                Copacabana        1      0       1    40
# 8      Apartamento                Copacabana        4      3       1   243
# 9      Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 10     Apartamento           Barra da Tijuca        2      1       1    67
# ...

# %%
tipo_casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
tipo_casa = imoveis['Tipo'].isin(tipo_casa)

# %%
tipo_casa
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8         True
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20       False
# 21       False
# 22        True
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 32930    False
# 32931     True
# 32932    False
# 32933    False
# 32934    False
# 32935    False
# 32936    False
# 32937    False
# 32938    False
# 32939    False
# 32940    False
# 32941    False
# 32942    False
# 32943    False
# 32944    False
# 32945    False
# 32946    False
# 32947    False
# 32948    False
# 32949    False
# 32950    False
# 32951    False
# 32952     True
# 32953    False
# 32954    False
# 32955    False
# 32956    False
# ...

# %%
tipo_casa = imoveis[tipo_casa]

# %%
tipo_casa
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 7      Casa de Condomínio           Barra da Tijuca        5      4       5
# 8      Casa de Condomínio                     Ramos        2      2       0
# 18     Casa de Condomínio                   Taquara        3      1       1
# 22     Casa de Condomínio           Barra da Tijuca        4      3       2
# 31                   Casa              Campo Grande        4      1       2
# 59     Casa de Condomínio           Barra da Tijuca        5     10       5
# 74                   Casa                     Méier        2      0       0
# 82                   Casa               São Conrado        4      2       4
# 85     Casa de Condomínio   Freguesia (Jacarepaguá)        5      3       1
# 117          Casa de Vila                   Piedade        2      1       0
# ...

# %%
tipo_casa.index = range(tipo_casa.shape[0])

# %%
tipo_casa
# Out:
#                     Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0                   Casa           Jardim Botânico        2      0       1
# 1     Casa de Condomínio           Barra da Tijuca        5      4       5
# 2     Casa de Condomínio                     Ramos        2      2       0
# 3     Casa de Condomínio                   Taquara        3      1       1
# 4     Casa de Condomínio           Barra da Tijuca        4      3       2
# 5                   Casa              Campo Grande        4      1       2
# 6     Casa de Condomínio           Barra da Tijuca        5     10       5
# 7                   Casa                     Méier        2      0       0
# 8                   Casa               São Conrado        4      2       4
# 9     Casa de Condomínio   Freguesia (Jacarepaguá)        5      3       1
# 10          Casa de Vila                   Piedade        2      1       0
# ...

# %%
area_60_100 = (imoveis['Area'] >= 60) & (imoveis['Area'] <=100)

# %%
area_60_100 = imoveis[area_60_100]

# %%
area_60_100
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 1                         Casa           Jardim Botânico        2      0
# 5                  Apartamento              Vista Alegre        3      1
# 8           Casa de Condomínio                     Ramos        2      2
# 11                 Apartamento                    Grajaú        2      1
# 12                 Apartamento       Lins de Vasconcelos        3      1
# 17                        Flat                  Botafogo        3      1
# 20                 Apartamento           Barra da Tijuca        2      1
# 23                 Apartamento                    Olaria        3      1
# 24                 Apartamento                    Tijuca        2      1
# 32                 Apartamento                  Botafogo        2      1
# 41                 Apartamento           Barra da Tijuca        3      1
# 47                 Apartamento  Recreio dos Bandeirantes        2      2
# ...

# %%
area_60_100.index = range(area_60_100.shape[0])

# %%
area_60_100
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 0                         Casa           Jardim Botânico        2      0
# 1                  Apartamento              Vista Alegre        3      1
# 2           Casa de Condomínio                     Ramos        2      2
# 3                  Apartamento                    Grajaú        2      1
# 4                  Apartamento       Lins de Vasconcelos        3      1
# 5                         Flat                  Botafogo        3      1
# 6                  Apartamento           Barra da Tijuca        2      1
# 7                  Apartamento                    Olaria        3      1
# 8                  Apartamento                    Tijuca        2      1
# 9                  Apartamento                  Botafogo        2      1
# 10                 Apartamento           Barra da Tijuca        3      1
# 11                 Apartamento  Recreio dos Bandeirantes        2      2
# ...

# %%
quarto_valor = (imoveis['Quartos'] >= 4) & (imoveis['Valor'] < 2000.0)

# %%
quarto_valor = imoveis[quarto_valor]

# %%
quarto_valor
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 701           Apartamento  Recreio dos Bandeirantes        4      2       2
# 1465          Apartamento                   Taquara        4      1       1
# 2874                 Casa              Campo Grande        4      1       4
# 3075                 Casa         Engenho de Dentro        4      3       0
# 3218          Apartamento  Recreio dos Bandeirantes        4      2       2
# 3419         Casa de Vila                     Méier        4      0       1
# 4721        Pousada/Chalé           Barra da Tijuca       23      0      23
# 5849                 Casa              Campo Grande        4      1       0
# 5852          Apartamento              Campo Grande        4      2       1
# 6456          Apartamento  Recreio dos Bandeirantes        4      2       1
# 7520          Apartamento               Cidade Nova        4      0       0
# ...

# %%
quarto_valor.index = range(quarto_valor.shape[0])

# %%
quarto_valor
# Out:
#                   Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0          Apartamento  Recreio dos Bandeirantes        4      2       2
# 1          Apartamento                   Taquara        4      1       1
# 2                 Casa              Campo Grande        4      1       4
# 3                 Casa         Engenho de Dentro        4      3       0
# 4          Apartamento  Recreio dos Bandeirantes        4      2       2
# 5         Casa de Vila                     Méier        4      0       1
# 6        Pousada/Chalé           Barra da Tijuca       23      0      23
# 7                 Casa              Campo Grande        4      1       0
# 8          Apartamento              Campo Grande        4      2       1
# 9          Apartamento  Recreio dos Bandeirantes        4      2       1
# 10         Apartamento               Cidade Nova        4      0       0
# 11         Apartamento                 Pechincha        4      1       2
# ...
